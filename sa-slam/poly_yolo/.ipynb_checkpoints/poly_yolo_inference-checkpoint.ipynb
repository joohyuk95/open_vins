# %%
import cv2
import numpy as np
import os
import time
import poly_yolo as yolo #or "import poly_yolo_lite as yolo" for the lite version
# Out:
# Using TensorFlow backend.

# %%
#load pretrained model
#if you want to detect more objects, lower the score and vice versa
trained_model = yolo.YOLO(model_path='models/logep074-loss10.957-val_loss11.376.h5', iou=0.5, score=0.3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 3>()
#       1 #load pretrained model
#       2 #if you want to detect more objects, lower the score and vice versa
# ----> 3 trained_model = yolo.YOLO(model_path='models/logep074-loss10.957-val_loss11.376.h5', iou=0.5, score=0.3)
#
# NameError: name 'yolo' is not defined

# %%
#helper function
def translate_color(cls):
    if cls == 0: return (230, 25, 75)
    if cls == 1: return (60, 180, 75)
    if cls == 2: return (255, 225, 25)
    if cls == 3: return (0, 130, 200)
    if cls == 4: return (245, 130, 48)
    if cls == 5: return (145, 30, 180)
    if cls == 7: return (70, 240, 240)
    if cls == 8: return (240, 50, 230)
    if cls == 9: return (210, 245, 60)
    if cls == 10: return (250, 190, 190)
    if cls == 11: return (0, 128, 128)
    if cls == 12: return (230, 190, 255)
    if cls == 13: return (170, 110, 40)
    if cls == 14: return (255, 250, 200)
    if cls == 15: return (128, 0, 128)
    if cls == 16: return (170, 255, 195)
    if cls == 17: return (128, 128, 0)
    if cls == 18: return (255, 215, 180)
    if cls == 19: return (80, 80, 128)

# %%
dir_imgs_name = '~/output_yolo_1/imgs'  #path_where_are_images_to_clasification
out_path       = '~/output_yolo_1/predict/' #path, where the images will be saved. The path must exist
list_of_imgs = [root+"/"+name for root, dirs, files in os.walk(dir_imgs_name) for name in files]    
list_of_imgs.sort()

#browse all images
total_boxes = 0
imgs        = 0
for im in range (0, len(list_of_imgs)):
    imgs    += 1
    img     = cv2.imread(list_of_imgs[im])
    overlay = img.copy()
    boxes   = []
    scores  = []
    classes = []
    
    #realize prediciction using poly-yolo
    startx = time.time()
    box, scores, classes, polygons = trained_model.detect_image(img)
    print('Prediction speed: ', 1.0/(time.time() - startx), 'fps')
    
    
    #example, hw to reshape reshape y1,x1,y2,x2 into x1,y1,x2,y2
    for k in range (0, len(box)):
        boxes.append((box[k][1], box[k][0], box[k][3], box[k][2]))
        cv2.rectangle(img, (box[k][1],box[k][0]), (box[k][3],box[k][2]), translate_color(classes[k]), 3, 1)
    total_boxes += len(boxes)
    
    #browse all boxes
    for b in range(0, len(boxes)):
        f              = translate_color(classes[b])    
        points_to_draw = []
        offset         = len(polygons[b])//3
        
        #filter bounding polygon vertices
        for dst in range(0, len(polygons[b])//3):
            if polygons[b][dst+offset*2] > 0.3: 
                points_to_draw.append([int(polygons[b][dst]), int(polygons[b][dst+offset])])
        
        points_to_draw = np.asarray(points_to_draw)
        points_to_draw = points_to_draw.astype(np.int32)
        if points_to_draw.shape[0]>0:
            cv2.polylines(img, [points_to_draw],True,f, thickness=2)
            cv2.fillPoly(overlay, [points_to_draw], f)
    img = cv2.addWeighted(overlay, 0.4, img, 1 - 0.4, 0)
    cv2.imwrite(out_path+str(imgs)+'.jpg', img)
    
print('total boxes: ', total_boxes)
print('imgs: ', imgs)
# Out:
# OMP: Info #254: KMP_AFFINITY: pid 62835 tid 63502 thread 1 bound to OS proc set 1
# OMP: Info #254: KMP_AFFINITY: pid 62835 tid 63552 thread 2 bound to OS proc set 2
# OMP: Info #254: KMP_AFFINITY: pid 62835 tid 63553 thread 3 bound to OS proc set 3
# OMP: Info #254: KMP_AFFINITY: pid 62835 tid 63554 thread 4 bound to OS proc set 4
# OMP: Info #254: KMP_AFFINITY: pid 62835 tid 63557 thread 7 bound to OS proc set 7
# OMP: Info #254: KMP_AFFINITY: pid 62835 tid 63555 thread 5 bound to OS proc set 5
# OMP: Info #254: KMP_AFFINITY: pid 62835 tid 63556 thread 6 bound to OS proc set 6
# OMP: Info #254: KMP_AFFINITY: pid 62835 tid 63558 thread 8 bound to OS proc set 8
# OMP: Info #254: KMP_AFFINITY: pid 62835 tid 63559 thread 9 bound to OS proc set 9
# OMP: Info #254: KMP_AFFINITY: pid 62835 tid 63560 thread 10 bound to OS proc set 10
# OMP: Info #254: KMP_AFFINITY: pid 62835 tid 63561 thread 11 bound to OS proc set 11
# OMP: Info #254: KMP_AFFINITY: pid 62835 tid 63563 thread 13 bound to OS proc set 13
# OMP: Info #254: KMP_AFFINITY: pid 62835 tid 63564 thread 14 bound to OS proc set 14
# OMP: Info #254: KMP_AFFINITY: pid 62835 tid 63562 thread 12 bound to OS proc set 12
# OMP: Info #254: KMP_AFFINITY: pid 62835 tid 63565 thread 15 bound to OS proc set 15
# OMP: Info #254: KMP_AFFINITY: pid 62835 tid 63567 thread 17 bound to OS proc set 17
# OMP: Info #254: KMP_AFFINITY: pid 62835 tid 63568 thread 18 bound to OS proc set 18
# OMP: Info #254: KMP_AFFINITY: pid 62835 tid 63566 thread 16 bound to OS proc set 16
# OMP: Info #254: KMP_AFFINITY: pid 62835 tid 63569 thread 19 bound to OS proc set 19
# OMP: Info #254: KMP_AFFINITY: pid 62835 tid 63570 thread 20 bound to OS proc set 0
# OMP: Info #254: KMP_AFFINITY: pid 62835 tid 63501 thread 21 bound to OS proc set 1
# OMP: Info #254: KMP_AFFINITY: pid 62835 tid 63571 thread 22 bound to OS proc set 2
# OMP: Info #254: KMP_AFFINITY: pid 62835 tid 63572 thread 23 bound to OS proc set 3
# OMP: Info #254: KMP_AFFINITY: pid 62835 tid 63573 thread 24 bound to OS proc set 4
# OMP: Info #254: KMP_AFFINITY: pid 62835 tid 63574 thread 25 bound to OS proc set 5
# OMP: Info #254: KMP_AFFINITY: pid 62835 tid 63576 thread 27 bound to OS proc set 7
# OMP: Info #254: KMP_AFFINITY: pid 62835 tid 63575 thread 26 bound to OS proc set 6
# OMP: Info #254: KMP_AFFINITY: pid 62835 tid 63578 thread 29 bound to OS proc set 9
# OMP: Info #254: KMP_AFFINITY: pid 62835 tid 63577 thread 28 bound to OS proc set 8
# OMP: Info #254: KMP_AFFINITY: pid 62835 tid 63579 thread 30 bound to OS proc set 10
# OMP: Info #254: KMP_AFFINITY: pid 62835 tid 63580 thread 31 bound to OS proc set 11
# OMP: Info #254: KMP_AFFINITY: pid 62835 tid 63581 thread 32 bound to OS proc set 12
# OMP: Info #254: KMP_AFFINITY: pid 62835 tid 63582 thread 33 bound to OS proc set 13
# OMP: Info #254: KMP_AFFINITY: pid 62835 tid 63583 thread 34 bound to OS proc set 14
# OMP: Info #254: KMP_AFFINITY: pid 62835 tid 63584 thread 35 bound to OS proc set 15
# OMP: Info #254: KMP_AFFINITY: pid 62835 tid 63585 thread 36 bound to OS proc set 16
# OMP: Info #254: KMP_AFFINITY: pid 62835 tid 63586 thread 37 bound to OS proc set 17
# OMP: Info #254: KMP_AFFINITY: pid 62835 tid 63587 thread 38 bound to OS proc set 18
# OMP: Info #254: KMP_AFFINITY: pid 62835 tid 63588 thread 39 bound to OS proc set 19
# OMP: Info #254: KMP_AFFINITY: pid 62835 tid 63589 thread 40 bound to OS proc set 0
# Prediction speed:  0.2536628614955408 fps
# Prediction speed:  0.8131775625014662 fps
# Prediction speed:  0.8486455130362048 fps
# Prediction speed:  0.7723949764449498 fps
# Prediction speed:  0.8116901225013649 fps
# Prediction speed:  0.8014306238572464 fps
# Prediction speed:  0.869765481024872 fps
# Prediction speed:  0.7559050577088258 fps
# Prediction speed:  0.7833858042999795 fps
# Prediction speed:  0.8499895430897657 fps
# Prediction speed:  0.8723550464806332 fps
# Prediction speed:  0.7698832630258514 fps
# Prediction speed:  0.7806159234850839 fps
# Prediction speed:  0.8618451766469625 fps
# Prediction speed:  0.7790112363390389 fps
# Prediction speed:  0.780306302907314 fps
# Prediction speed:  0.8298644059479989 fps
# Prediction speed:  0.8505611187495183 fps
# Prediction speed:  0.7894829073527831 fps
# Prediction speed:  0.7682891400657743 fps
# Prediction speed:  0.7915195413218173 fps
# Prediction speed:  0.7825015923145033 fps
# Prediction speed:  0.8256549445548125 fps
# Prediction speed:  0.7814109948146314 fps
# Prediction speed:  0.8150421706143989 fps
# Prediction speed:  0.8889122486366338 fps
# Prediction speed:  0.7841746552330797 fps
# Prediction speed:  0.7675022758983508 fps
# Prediction speed:  0.896828186673851 fps
# Prediction speed:  0.8807703178817015 fps
# Prediction speed:  0.8021296777944371 fps
# Prediction speed:  0.8207111022580051 fps
# Prediction speed:  0.8153655523885913 fps
# Prediction speed:  0.8901892926521834 fps
# Prediction speed:  0.8017095781485941 fps
# Prediction speed:  0.861083646755465 fps
# Prediction speed:  0.8246802580271712 fps
# Prediction speed:  0.7559012432719032 fps
# Prediction speed:  0.8500315749453011 fps
# Prediction speed:  0.8807978769983728 fps
# Prediction speed:  0.8411168435978983 fps
# Prediction speed:  0.8488366680576811 fps
# Prediction speed:  0.7787017305827884 fps
# Prediction speed:  0.839220489901972 fps
# Prediction speed:  0.8752317557975727 fps
# Prediction speed:  0.8624411484152816 fps
# Prediction speed:  0.8369819429345007 fps
# Prediction speed:  0.8149202362825388 fps
# Prediction speed:  0.7514521826903335 fps
# Prediction speed:  0.8278597035434919 fps
# Prediction speed:  0.8486513511780002 fps
# Prediction speed:  0.8792491077651942 fps
# Prediction speed:  0.7669184783055877 fps
# Prediction speed:  0.7985956093752975 fps
# Prediction speed:  0.8300291241136064 fps
# Prediction speed:  0.8585066955189158 fps
# Prediction speed:  0.7860930465045103 fps
# Prediction speed:  0.8178704812469886 fps
# Prediction speed:  0.8125178342874334 fps
# Prediction speed:  0.8458974828004237 fps
# Prediction speed:  0.8069355256378734 fps
# Prediction speed:  0.8714294292010751 fps
# Prediction speed:  0.81510616114573 fps
# Prediction speed:  0.8560782456770569 fps
# Prediction speed:  0.7685243734112771 fps
# Prediction speed:  0.8356933550457057 fps
# Prediction speed:  0.8801554031098668 fps
# Prediction speed:  0.8211865657819875 fps
# Prediction speed:  0.8456189869436537 fps
# Prediction speed:  0.8050139869199506 fps
# Prediction speed:  0.8212767715549457 fps
# Prediction speed:  0.8741872304967103 fps
# Prediction speed:  0.7933816263560659 fps
# Prediction speed:  0.841106385828886 fps
# Prediction speed:  0.8394942823854881 fps
# Prediction speed:  0.8237289001050698 fps
# Prediction speed:  0.8186042735306298 fps
# Prediction speed:  0.799582432422643 fps
# Prediction speed:  0.856060598329517 fps
# Prediction speed:  0.7871035469074271 fps
# Prediction speed:  0.7677723019033845 fps
# Prediction speed:  0.8301889780112853 fps
# Prediction speed:  0.8534100763455698 fps
# Prediction speed:  0.8287182826819126 fps
# Prediction speed:  0.8307447560314749 fps
# Prediction speed:  0.8449840615000663 fps
# Prediction speed:  0.8006007315211877 fps
# Prediction speed:  0.7590924778736237 fps
# Prediction speed:  0.7685078981641431 fps
# Prediction speed:  0.775942709460672 fps
# Prediction speed:  0.8608196198465906 fps
# Prediction speed:  0.8265897446054344 fps
# Prediction speed:  0.8179210398739784 fps
# Prediction speed:  0.82866048660617 fps
# Prediction speed:  0.801156301447497 fps
# Prediction speed:  0.8193890035963374 fps
# Prediction speed:  0.8423949839155191 fps
# Prediction speed:  0.8177948942022857 fps
# Prediction speed:  0.8149069365625193 fps
# Prediction speed:  0.7598586048021612 fps
# Prediction speed:  0.8304986749417466 fps
# Prediction speed:  0.8181890890278924 fps
# Prediction speed:  0.9137853505160748 fps
# Prediction speed:  0.8025436148161698 fps
# Prediction speed:  0.8010368033881745 fps
# Prediction speed:  0.846519259742894 fps
# Prediction speed:  0.8745309953313771 fps
# Prediction speed:  0.8190870555739775 fps
# Prediction speed:  0.8483161316028454 fps
# Prediction speed:  0.781545969982164 fps
# Prediction speed:  0.8661858451452914 fps
# Prediction speed:  0.8447607782272951 fps
# Prediction speed:  0.8589780663130516 fps
# Prediction speed:  0.7454747329220189 fps
# Prediction speed:  0.817648703222051 fps
# Prediction speed:  0.8370587798587201 fps
# Prediction speed:  0.7981166269476706 fps
# Prediction speed:  0.8725399703141561 fps
# Prediction speed:  0.8757143632635846 fps
# Prediction speed:  0.8084788129908541 fps
# total boxes:  114
# imgs:  120
